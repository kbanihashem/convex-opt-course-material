# %%
# %matplotlib inline

# %%
from code import *

# %%
parta(should_plot=True, num_tests=1, random_state=0)
# Out:
# 1th data point
# num_steps: 12
# primal_slackness: 0.000000
# dual_slackness: 0.000000
# Our optimal value: 278.610140
# CVX optimal value: 278.610136
# Relative error: 0.000000

# %%
parta(should_plot=False, num_tests=5, random_state=0)
# Out:
# 1th data point
# num_steps: 12
# primal_slackness: 0.000000
# dual_slackness: 0.000000
# Our optimal value: 278.610140
# CVX optimal value: 278.610136
# Relative error: 0.000000
# 2th data point
# num_steps: 17
# primal_slackness: 0.000000
# dual_slackness: 0.000042
# Our optimal value: 240.011720
# CVX optimal value: 240.011717
# Relative error: 0.000000
# 3th data point
# num_steps: 13
# primal_slackness: 0.000000
# dual_slackness: 0.000001
# Our optimal value: 207.055352
# CVX optimal value: 207.055350
# Relative error: 0.000000
# 4th data point
# num_steps: 12
# primal_slackness: 0.000000
# dual_slackness: 0.000013
# Our optimal value: 211.737818
# CVX optimal value: 211.737816
# Relative error: 0.000001
# 5th data point
# num_steps: 15
# primal_slackness: 0.000000
# dual_slackness: 0.000000
# Our optimal value: 238.542511
# CVX optimal value: 238.542508
# Relative error: 0.000000

# %%
partb(should_plot=True, num_tests=1)
# Out:
# 1th data point
# Our optimal value: -202.489234
# CVX optimal value: -202.489266
# Relative error: 0.000001

# %%
partb(should_plot=False, num_tests=5)
# Out:
# 1th data point
# Our optimal value: -202.489234
# CVX optimal value: -202.489266
# Relative error: 0.000001
# 2th data point
# Our optimal value: -256.263014
# CVX optimal value: -256.263031
# Relative error: 0.000005
# 3th data point
# Our optimal value: -324.489891
# CVX optimal value: -324.489969
# Relative error: 0.000000
# 4th data point
# Our optimal value: -264.981087
# CVX optimal value: -264.981099
# Relative error: 0.000001
# 5th data point
# Our optimal value: -265.386836
# CVX optimal value: -265.386883
# Relative error: 0.000000

# %%
partc(num_tests=5)
# Out:
# ++++++++++
# 1the data point
# infeasible3
# infeasible4
# feasible1
# Our optimal value: -167.049984
# CVX optimal value: -167.050008
# Relative error: 0.000002
# feasible2
# Our optimal value: -202.492542
# CVX optimal value: -202.489266
# Relative error: 0.000017
# ----------
# ++++++++++
# 2the data point
# infeasible3
# infeasible4
# feasible1
# Our optimal value: -167.049984
# CVX optimal value: -167.050008
# Relative error: 0.000002
# feasible2
# Our optimal value: -202.492542
# CVX optimal value: -202.489266
# Relative error: 0.000017
# ----------
# ++++++++++
# 3the data point
# infeasible3
# infeasible4
# feasible1
# Our optimal value: -167.049984
# CVX optimal value: -167.050008
# Relative error: 0.000002
# feasible2
# Our optimal value: -202.492542
# CVX optimal value: -202.489266
# Relative error: 0.000017
# ----------
# ++++++++++
# 4the data point
# infeasible3
# infeasible4
# feasible1
# Our optimal value: -167.049984
# CVX optimal value: -167.050008
# ...
