# %%
# %matplotlib inline
from q2 import *

# %%
eigth_twelve(should_plot=True, num_tests=1, should_be_infeasible=True)
# Out:
# 1th data point
# num_steps: 100
# maxed out iterations: True
# primal_slackness: 28.442500
# dual_slackness: 3510.461245
# CVX status: infeasible

# %%
eigth_twelve(should_plot=True, num_tests=1, should_be_unbounded=True)
# Out:
# 1th data point
# num_steps: 100
# maxed out iterations: True
# primal_slackness: 0.000212
# dual_slackness: 700.555074
# CVX status: unbounded

# %%
eigth_twelve(should_plot=False, num_tests=10)
# Out:
# 1th data point
# num_steps: 8
# maxed out iterations: False
# primal_slackness: 0.000000
# dual_slackness: 0.000000
# CVX status: optimal
# Our optimal value: 278.610140
# CVX optimal value: 278.610136
# Relative error: 0.000000
# 2th data point
# num_steps: 11
# maxed out iterations: False
# primal_slackness: 0.000000
# dual_slackness: 0.000000
# CVX status: optimal
# Our optimal value: 240.011720
# CVX optimal value: 240.011717
# Relative error: 0.000000
# 3th data point
# num_steps: 10
# maxed out iterations: False
# primal_slackness: 0.000000
# dual_slackness: 0.000000
# CVX status: optimal
# Our optimal value: 207.055352
# CVX optimal value: 207.055350
# Relative error: 0.000000
# 4th data point
# num_steps: 9
# maxed out iterations: False
# primal_slackness: 0.000000
# dual_slackness: 0.000000
# CVX status: optimal
# Our optimal value: 211.737818
# CVX optimal value: 211.737816
# Relative error: 0.000000
# 5th data point
# num_steps: 8
# maxed out iterations: False
# ...

# %%
eigth_twelve(should_plot=True, random_state=40)
# Out:
# 1th data point
# num_steps: 9
# maxed out iterations: False
# primal_slackness: 0.000000
# dual_slackness: 0.000000
# CVX status: optimal
# Our optimal value: 255.700154
# CVX optimal value: 255.700150
# Relative error: 0.000000

# %%
nine_eight(should_plot=True)
# Out:
# 1th data point
# Our optimal value: -202.486066
# CVX optimal value: -202.489266
# Relative error: 0.000093
# Relative error v: 0.000055
# Relative error lambda: 0.000048
# centering steps: 4
# newton steps: 130
# evaluating mu
# ----------
