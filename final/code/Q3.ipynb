# %%
import json
import numpy as np
import cvxpy as cp
with open("Recon3D.json", "r") as file_handle:
    dictionary = json.load(file_handle);
    data = dictionary["reactions"];
    temp_name = [(data[i])["name"] for i in range(len(data))];
    b = [i for i in range(len(data)) if temp_name[i] == "Generic Human Biomass Reaction"];
    b = b[0];
    order = [i for j in (range(b), range(b+1, len(data)), range(b,b+1)) for i in j];
    name = [(data[i])["name"] for i in order];
    lower_bound = [(data[i])["lower_bound"] for i in order];
    upper_bound = [(data[i])["upper_bound"] for i in order];
    subsystem = [(data[i])["subsystem"] for i in order];
    metabolites = [(data[i])["metabolites"] for i in order];
    id = [((dictionary["metabolites"])[i])["id"] for i in range(len(dictionary["metabolites"]))];
    S = np.zeros((len(id), len(metabolites)));
    for i in range(len(metabolites)):
        for j in range(len(id)):
            if id[j] in metabolites[i].keys():
                S[j, i] = metabolites[i][id[j]];
knockout_names = [
        'Transport, nuclear',
        'Fatty acid oxidation',
        ]

# %%
def solve_with_removed_index(removed=None):
    solvers = {'ECOS': cp.ECOS, 'QSOP': cp.OSQP, 'SCS': cp.SCS}
    for solver_name, solver in solvers.items():
        u = np.array(upper_bound.copy())
        l = np.array(lower_bound.copy())
        if removed is not None:
            removed = np.array(removed)
            u[removed] = 0
            l[removed] = 0
        m, n = S.shape
        v = cp.Variable(n)
        constraints = [
                S @ v == 0,
                v <= u,
                v >= l,
                ]
        obj = cp.Maximize(v[-1])
        problem = cp.Problem(obj, constraints)
        ans = problem.solve(solver=solver)
        if problem.status == 'optimal':
            return problem, v.value, solver_name

def get_knockout_index(knockout):
    return [i for i, sub_name in enumerate(subsystem) if sub_name in knockout]

def get_subystem_indexes(name):
    return get_knockout_index({name})

def part_a():
    #should run read_data before this
    p_a, v_a, solver_a = solve_with_removed_index()
    return p_a, v_a, solver_a

def evaluated_diff(v_w, v_tilde):
    return (v_w[-1] - v_tilde[-1]) / v_w[-1]

def part_b():
    p_transport, v_transport, solver_transport = solve_with_removed_index(get_subystem_indexes(knockout_names[0]))
    p_fatty, v_fatty, solver_fatty = solve_with_removed_index(get_subystem_indexes(knockout_names[1]))
    return p_transport, v_transport, solver_transport, p_fatty, v_fatty, solver_fatty

def part_c(v_a):
    possible_indexes = get_subystem_indexes(knockout_names[0])
    print('length of list: ', len(possible_indexes))
    li = []
    for i, index in enumerate(possible_indexes):
        print(f'starting {i}th index {index}, name={name[index]}')
        p_index, v_index, solver_index = solve_with_removed_index([index])
        evaluation = evaluated_diff(v_a, v_index)
        made_it = evaluation > 0.2
        print(f'status: {p_index.status}, solver: {solver_index}, evaluation: {evaluation}, made it: {made_it}')
        if made_it:
            li.append(name[index])
    return li

def main():
    p_a, v_a, solver_a = part_a()
    p_transport, v_transport, solver_transport, p_fatty, v_fatty, solver_fatty = part_b()
    print(p_a.status, p_transport.status, p_fatty.status)
    print(p_a.value, p_transport.value, p_fatty.value)
    print(evaluated_diff(v_a, v_transport), evaluated_diff(v_a, v_fatty))

# %%
li_c = part_c(v_a)
# Out:
# length of list:  71
# starting 0th index 50, name=35cGMP nuclear transport
# status: optimal, solver: ECOS, evaluation: -8.743789840439052e-13, made it: False
# starting 1th index 161, name=Acetyl CoA transport  nuclear
# status: optimal, solver: ECOS, evaluation: -3.44982802472276e-13, made it: False
# starting 2th index 184, name=Acetylcholin transport, nuclear trhough pores
# status: optimal, solver: ECOS, evaluation: -3.4453006913569824e-13, made it: False
# starting 3th index 199, name=N-acetylneuraminate nuclear import
# status: optimal, solver: ECOS, evaluation: -8.266910725910447e-13, made it: False
# starting 4th index 386, name=ATP diffusion in nucleus
# status: optimal, solver: ECOS, evaluation: -1.720084856771217e-12, made it: False
# starting 5th index 439, name=Biocytin transport, nuclear
# status: optimal, solver: ECOS, evaluation: -1.2970810092953686e-12, made it: False
# starting 6th index 452, name=Biotin transport, nuclear
# status: optimal, solver: ECOS, evaluation: 8.88262806365624e-13, made it: False
# starting 7th index 527, name=Choline transport, nuclear through pores
# status: optimal, solver: ECOS, evaluation: -3.44982802472276e-13, made it: False
# starting 8th index 557, name=CMP-Sia nuclear export
# status: optimal, solver: ECOS, evaluation: -2.3481769057168044e-12, made it: False
# starting 9th index 567, name=Coenzyme A transport  nuclear
# status: optimal, solver: ECOS, evaluation: -3.4453006913569824e-13, made it: False
# starting 10th index 626, name=CTP diffusion in nucleus
# status: optimal, solver: ECOS, evaluation: -2.2472173716599573e-12, made it: False
# starting 11th index 651, name=Cytidine  transport in nucleus
# status: optimal, solver: ECOS, evaluation: 1.6863562231961718e-11, made it: False
# starting 12th index 696, name=DATP diffusion in nucleus
# status: optimal, solver: QSOP, evaluation: 1.000000374150002, made it: True
# starting 13th index 707, name=DCTP diffusion in nucleus
# status: optimal, solver: ECOS, evaluation: 0.010843971965290716, made it: False
# starting 14th index 738, name=DGTP diffusion in nucleus
# status: optimal, solver: QSOP, evaluation: 0.999999398567834, made it: True
# starting 15th index 760, name=DIDP nuclear transport
# status: optimal, solver: ECOS, evaluation: 0.0034706916742795577, made it: False
# starting 16th index 765, name=DITP nuclear transport
# status: optimal, solver: ECOS, evaluation: 0.0034706916742794068, made it: False
# starting 17th index 818, name=DNAD transport, nuclear trhough pore
# status: optimal, solver: ECOS, evaluation: 2.420614239569251e-13, made it: False
# starting 18th index 904, name=DTDP nuclear transport
# status: optimal, solver: ECOS, evaluation: 0.0034706916706786677, made it: False
# starting 19th index 905, name=DTTP diffusion in nucleus
# status: optimal, solver: ECOS, evaluation: 0.0034358378174083183, made it: False
# starting 20th index 906, name=DUDP nuclear transport
# status: optimal, solver: ECOS, evaluation: 0.01063829782240059, made it: False
# starting 21th index 907, name=DUMP nuclear transport
# status: optimal, solver: ECOS, evaluation: -1.214230808701633e-12, made it: False
# starting 22th index 913, name=Deoxyuridine  transport in nucleus
# status: optimal, solver: ECOS, evaluation: -5.4211798832946506e-12, made it: False
# starting 23th index 1696, name=GMP nuclear transport
# status: optimal, solver: ECOS, evaluation: -8.746808062682904e-13, made it: False
# starting 24th index 1742, name=Hydrogen peroxide nuclear transport
# status: optimal, solver: ECOS, evaluation: 1.5100165885991224e-12, made it: False
# starting 25th index 1748, name=H2O transport  nuclear
# status: optimal, solver: ECOS, evaluation: 3.3324633246043765e-05, made it: False
# starting 26th index 1813, name=4-hydroxyretinoic acid transport, Nuclear
# status: optimal, solver: ECOS, evaluation: 5.734622263318674e-15, made it: False
# starting 27th index 1864, name=IDP nuclear transport
# status: optimal, solver: ECOS, evaluation: 0.003470691668836647, made it: False
# starting 28th index 1879, name=ITP nuclear transport
# status: optimal, solver: ECOS, evaluation: 5.4587567502306075e-12, made it: False
# starting 29th index 1974, name=L-lysine transport, nuclear
# status: optimal, solver: ECOS, evaluation: -1.2970810092953686e-12, made it: False
# starting 30th index 2032, name=Inositol 1,4-bisphosphate nuclear transport (diffusion)
# status: optimal, solver: ECOS, evaluation: -3.2518477366372925e-11, made it: False
# starting 31th index 2033, name=Inositol 1-phosphate nuclear transport (diffusion)
# status: optimal, solver: ECOS, evaluation: -1.5110729663844705e-12, made it: False
# starting 32th index 2036, name=Inositol hexakisphosphate nuclear transport  diffusion
# status: optimal, solver: ECOS, evaluation: -1.2788207647200643e-12, made it: False
# starting 33th index 2117, name=NAD transport  nuclear through pores
# status: optimal, solver: ECOS, evaluation: -2.0582766591948263e-12, made it: False
# starting 34th index 2162, name=Ammonia nuclear transport
# status: optimal, solver: ECOS, evaluation: 3.332463174100724e-05, made it: False
# starting 35th index 2165, name=NICRNT transport, nuclear trhough pore
# status: optimal, solver: ECOS, evaluation: -4.1560920297841124e-13, made it: False
# starting 36th index 2173, name=NMN transport, nuclear trhough pore
# status: optimal, solver: ECOS, evaluation: -2.4203124173448655e-12, made it: False
# starting 37th index 2209, name=Superoxide anion transport via diffusion (nucleus)
# status: optimal, solver: ECOS, evaluation: 1.5229949442476856e-12, made it: False
# starting 38th index 2213, name=O2 transport (diffusion), nucleus
# status: optimal, solver: ECOS, evaluation: 2.906548020829412e-13, made it: False
# starting 39th index 2235, name=4-oxo-retinoic acid transport, Nuclear
# status: optimal, solver: ECOS, evaluation: -2.3391222389852487e-14, made it: False
# starting 40th index 2236, name=13-cis-4-oxo-retinoic acid transport, Nuclear
# status: optimal, solver: ECOS, evaluation: -2.8069466867822984e-14, made it: False
# starting 41th index 2298, name=Phosphatidate transport, nuclear
# status: optimal, solver: ECOS, evaluation: -4.788756685429136e-11, made it: False
# starting 42th index 2303, name=Phosphatidylinositol nuclear transport (diffusion)
# status: optimal, solver: ECOS, evaluation: 0.031914893586800636, made it: False
# starting 43th index 2304, name=Phosphatidylinositol 4,5-bisphosphate nuclear transport (diffusion)
# status: optimal, solver: ECOS, evaluation: 0.00028019870860337883, made it: False
# starting 44th index 2305, name=Phosphatidylinositol 4-phosphate nuclear transport (diffusion)
# status: optimal, solver: ECOS, evaluation: 3.017014954954393e-12, made it: False
# starting 45th index 2407, name=Phosphate transport, nuclear
# status: optimal, solver: ECOS, evaluation: 0.03210354180755039, made it: False
# starting 46th index 2428, name=5-diphosphatidylinositol pentakisphosphate nuclear transport (diffusion)
# status: optimal, solver: ECOS, evaluation: -1.2786698536078718e-12, made it: False
# starting 47th index 2491, name=Retinoate transport, nuclear
# status: optimal, solver: ECOS, evaluation: -7.439917831095016e-14, made it: False
# starting 48th index 2492, name=13-cis-retinoic acid transport, nuclear
# status: optimal, solver: ECOS, evaluation: -6.791000048666851e-14, made it: False
# starting 49th index 2899, name=Uridine  transport in nucleus
# status: optimal, solver: ECOS, evaluation: 1.6864014965298295e-11, made it: False
# starting 50th index 2901, name=UTP diffusion in nucleus
# status: optimal, solver: ECOS, evaluation: -5.5791989088715185e-11, made it: False
# starting 51th index 3441, name=Transport reaction
# status: optimal, solver: ECOS, evaluation: 6.926216405191418e-12, made it: False
# starting 52th index 5314, name=Tanslocation of 1-alpha,25-Dihydroxyvitamin D3 to nucleus
# status: optimal, solver: ECOS, evaluation: 5.281888926740884e-15, made it: False
# starting 53th index 5318, name=Transport of GABA
# status: optimal, solver: ECOS, evaluation: 1.978595591957135e-12, made it: False
# starting 54th index 8191, name=UDPgalactose Transport (Nuclear)
# status: optimal, solver: ECOS, evaluation: 0.0034706917116987227, made it: False
# starting 55th index 8197, name=Phosphatidylcholine Scramblase
# status: optimal, solver: ECOS, evaluation: -5.252310348751135e-12, made it: False
# starting 56th index 8198, name=Choline Phosphate Intracellular Transport
# status: optimal, solver: ECOS, evaluation: -5.252461259863328e-12, made it: False
# starting 57th index 8202, name=Sphinganine Intracellular Transport
# status: optimal, solver: ECOS, evaluation: -5.716512929855562e-13, made it: False
# starting 58th index 8204, name=Sphingosine Intracellular Transport
# status: optimal, solver: ECOS, evaluation: -6.013807820874978e-13, made it: False
# starting 59th index 8211, name=Transport of Gd1A
# status: optimal, solver: ECOS, evaluation: -7.436899608851165e-13, made it: False
# starting 60th index 8226, name=Galactocerebroside Intracellular Transport
# status: optimal, solver: ECOS, evaluation: 0.003470691713837586, made it: False
# starting 61th index 8227, name=Ceramide Transport Protei
# status: optimal, solver: ECOS, evaluation: 0.003470691713837435, made it: False
# starting 62th index 8232, name=Transport of Gd1A
# status: optimal, solver: ECOS, evaluation: -9.345925178087513e-13, made it: False
# starting 63th index 8552, name=HMR 0984
# status: optimal, solver: ECOS, evaluation: 1.2374711199792928e-14, made it: False
# starting 64th index 8564, name=HMR 1095
# status: optimal, solver: ECOS, evaluation: 2.997849243705933e-11, made it: False
# starting 65th index 8815, name=Prostaglandin-Endoperoxide Synthase
# status: optimal, solver: ECOS, evaluation: -1.4608195660243358e-13, made it: False
# starting 66th index 9336, name=HMR 6617
# status: optimal, solver: ECOS, evaluation: 0.010638297820645796, made it: False
# starting 67th index 9337, name=HMR 6619
# status: optimal, solver: ECOS, evaluation: 0.010638297820646098, made it: False
# starting 68th index 9395, name=AMP transport via diffusion  cytosol to nucleus
# status: optimal, solver: ECOS, evaluation: -8.063180724450441e-13, made it: False
# starting 69th index 9427, name=HMR 8476
# status: optimal, solver: ECOS, evaluation: -2.6193490832156812e-11, made it: False
# starting 70th index 9524, name=HMR 9674
# status: optimal, solver: ECOS, evaluation: -5.126254296736659e-11, made it: False

# %%
li_c
# Out:
# ['DATP diffusion in nucleus', 'DGTP diffusion in nucleus']

# %%
main()
# Out:
# optimal optimal optimal
# 753.3364247990297 0.0007596634022799669 753.3364248096925
# 0.9999989916013918 -1.4154255034768028e-11
